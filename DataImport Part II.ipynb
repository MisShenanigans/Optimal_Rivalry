# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from scipy.integrate import quad

# %%
WinRate_df = pd.read_csv("MarvelRivals_WinRate_Matrix.csv", index_col=0)
NumMatches_df = pd.read_csv("MarvelRivals_NumMatches_Matrix.csv", index_col=0)

WinRate_df.head()
# Out:
#                  Captain America  Doctor Strange  Groot   Hulk  Magneto  \
# Captain America            50.00           52.79  52.12  52.00    53.99
# Doctor Strange             47.21           50.00  49.60  48.00    50.90
# Groot                      47.88           50.40  50.00  48.41    52.23
# Hulk                       48.00           52.00  51.59  50.00    52.66
# Magneto                    46.01           49.10  47.77  47.34    50.00
#
#                  Peni Parker  The Thing   Thor  Venom  Black Panther  ...  \
# Captain America        50.08      52.69  51.17  54.07          50.34  ...
# Doctor Strange         46.66      48.71  47.62  50.13          47.00  ...
# Groot                  46.77      50.15  48.18  50.94          47.20  ...
# Hulk                   47.53      50.91  50.05  51.05          47.97  ...
# Magneto                45.40      47.82  46.35  48.67          46.24  ...
#
#                  Winter Soldier  Wolverine  Adam Warlock  Cloak & Dagger  \
# Captain America           52.59      52.65         50.64           54.92
# Doctor Strange            49.59      48.66         48.00           52.78
# Groot                     50.74      51.22         49.52           53.12
# Hulk                      50.89      51.05         49.69           54.54
# Magneto                   48.31      46.79         47.48           51.71
#
#                  Invisible Woman  Jeff The Land Shark   Loki  Luna Snow  \
# Captain America            54.71                57.58  49.89      55.90
# Doctor Strange             51.06                53.11  47.74      51.83
# Groot                      51.63                53.75  48.65      53.75
# Hulk                       53.12                56.46  49.99      53.76
# Magneto                    50.17                52.85  47.28      51.34
#
#                  Mantis  Rocket Raccoon
# Captain America   49.80           47.98
# Doctor Strange    46.90           45.29
# Groot             47.86           46.76
# Hulk              47.89           46.06
# Magneto           46.06           43.71
#
# [5 rows x 37 columns]

# %%
win_rates = WinRate_df.astype(float).values.flatten()
num_matches = NumMatches_df.astype(float).values.flatten()

valid_indices = np.isfinite(win_rates) & np.isfinite(num_matches)
win_rates = win_rates[valid_indices]
num_matches = num_matches[valid_indices]

kde = gaussian_kde(win_rates, weights=num_matches)

x_values = np.linspace(38, 62, 500)
kde_values = kde(x_values)

plt.figure(figsize=(10, 6))
plt.hist(win_rates, bins=np.linspace(38, 62, 50), weights=num_matches, edgecolor='black', alpha=0.5, density=True, label="Weighted Histogram")

plt.plot(x_values, kde_values, color='red', linewidth=2, label="Weighted Gaussian KDE")

plt.xlabel("Win Rate (%)")
plt.ylabel("Density (Weighted by Matches)")
plt.title("Win Rate Distribution with Weighted Gaussian KDE")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)

plt.show()

# %%
def utility_score(kde, winrate):
    total_cdf, _ = quad(kde, 38, 62)
    cdf, _ = quad(kde, 38, winrate)
    utility = ((cdf - (total_cdf / 2)) / (total_cdf/2))
    return round(utility, 2)

example_score = utility_score(kde, 60)
example_score
# Out:
# 0.99

# %%
Payoff_df = WinRate_df.copy()

for row_hero in WinRate_df.index:
    for col_hero in WinRate_df.columns:
        winrate = WinRate_df.at[row_hero, col_hero]
        Payoff_df.at[row_hero, col_hero] = utility_score(kde, winrate)

Payoff_df = Payoff_df.astype(float)

# %%
Payoff_df.to_csv("MarvelRivals_Payoff_Matrix.csv")
Payoff_df
# Out:
#                      Captain America  Doctor Strange  Groot  Hulk  Magneto  \
# Captain America                 0.00            0.54   0.43  0.40     0.71
# Doctor Strange                 -0.54            0.00  -0.08 -0.40     0.19
#                      Invisible Woman  Jeff The Land Shark  Loki  Luna Snow  \
# Captain America                 0.79                 0.96 -0.02       0.88
# Doctor Strange                  0.22                 0.59 -0.45       0.37
# Groot                           0.33                 0.68 -0.28       0.68
# Hulk                            0.59                 0.91 -0.00       0.68
# Magneto                         0.04                 0.55 -0.53       0.28
# Peni Parker                     0.76                 0.99  0.29       0.89
# The Thing                       0.48                 0.81 -0.20       0.58
# Thor                            0.69                 0.96  0.12       0.76
# Venom                           0.39                 0.80 -0.28       0.54
# Black Panther                   0.75                 0.96  0.37       0.85
# Black Widow                    -0.94                -0.67 -0.99      -0.84
# Hawkeye                        -0.32                 0.18 -0.70      -0.11
# Hela                            0.23                 0.68 -0.40       0.42
# Human Torch                     0.00                 0.63 -0.63       0.21
# Iron Fist                       0.75                 0.96 -0.19       0.80
# Iron Man                        0.62                 0.92  0.11       0.71
# Magik                           0.92                 0.98  0.62       0.95
# Mister Fantastic                0.70                 0.94 -0.00       0.74
# Moon Knight                    -0.71                -0.20 -0.97      -0.62
# Namor                          -0.23                 0.29 -0.74       0.15
# Psylocke                        0.25                 0.76 -0.53       0.51
# Scarlet Witch                   0.24                 0.73 -0.41       0.44
# Spider Man                      0.72                 0.91  0.06       0.78
# Squirrel Girl                  -0.46                 0.34 -0.85      -0.28
# Star Lord                       0.47                 0.84 -0.14       0.52
# Storm                           0.89                 0.99  0.69       0.96
# The Punisher                    0.03                 0.48 -0.48       0.28
# Winter Soldier                  0.31                 0.80 -0.17       0.58
# Wolverine                       0.66                 0.89 -0.24       0.77
# Adam Warlock                    0.59                 0.92 -0.03       0.70
# Cloak & Dagger                 -0.27                 0.39 -0.81      -0.12
# Invisible Woman                 0.00                 0.49 -0.56       0.27
# Jeff The Land Shark            -0.49                 0.00 -0.86      -0.04
# Loki                            0.56                 0.86  0.00       0.78
# Luna Snow                      -0.27                 0.04 -0.78       0.00
# Mantis                          0.75                 0.96  0.28       0.88
# Rocket Raccoon                  0.91                 0.99  0.66       0.95
#
#                      Mantis  Rocket Raccoon
# Captain America       -0.04           -0.41
# Doctor Strange        -0.59           -0.79
# Groot                 -0.43           -0.61
# Hulk                  -0.42           -0.70
# Magneto               -0.70           -0.90
# Peni Parker            0.02           -0.48
# The Thing             -0.49           -0.82
# Thor                  -0.18           -0.55
# Venom                 -0.65           -0.90
# Black Panther         -0.11           -0.66
# Black Widow           -0.98           -1.00
# Hawkeye               -0.85           -0.95
# Hela                  -0.64           -0.74
# Human Torch           -0.80           -0.96
# Iron Fist              0.08           -0.58
# Iron Man              -0.33           -0.69
# Magik                  0.32           -0.07
# Mister Fantastic      -0.04           -0.71
# Moon Knight           -0.97           -1.00
# Namor                 -0.88           -0.92
# Psylocke              -0.58           -0.69
# Scarlet Witch         -0.68           -0.88
# Spider Man            -0.33           -0.73
# Squirrel Girl         -0.94           -0.99
# Star Lord             -0.49           -0.65
# Storm                  0.38            0.06
# The Punisher          -0.68           -0.79
# Winter Soldier        -0.46           -0.72
# Wolverine             -0.04           -0.50
# Adam Warlock          -0.36           -0.65
# Cloak & Dagger        -0.88           -0.96
# Invisible Woman       -0.75           -0.91
# Jeff The Land Shark   -0.96           -0.99
# Loki                  -0.28           -0.66
# Luna Snow             -0.88           -0.95
# Mantis                 0.00           -0.31
# Rocket Raccoon         0.31            0.00
#
# [37 rows x 37 columns]
