# %% [markdown]
# ## 1. Imports
# If an import fails, install the dependencies in this notebook's kernel with `%pip install requests beautifulsoup4 pandas numpy scipy`.

# %%
from pathlib import Path
import re
import time

import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from requests.adapters import HTTPAdapter
from scipy.stats import gaussian_kde
from urllib3.util.retry import Retry


from IPython.display import display

# %% [markdown]
# ## 2. Hero lists and settings

# %%
vanguards = sorted([
    "Venom", "Emma Frost", "Magneto", "Doctor Strange", "The Thing", "Groot", "Hulk", "Thor", "Peni Parker",
    "Captain America", "Rogue", "Angela", "Deadpool Vanguard", "The Hood", "Devil Dinosaur"
])

duelists = sorted([
    "Moon Knight", "Squirrel Girl", "Human Torch", "Black Widow", "Namor", "The Punisher",
    "Hawkeye", "Scarlet Witch", "Psylocke", "Winter Soldier", "Wolverine", "Iron Man", "Hela",
    "Mister Fantastic", "Spider Man", "Iron Fist", "Star Lord", "Black Panther", "Storm", "Magik",
    "Phoenix", "Blade", "Daredevil", "Deadpool Duelist", "Cyclops", "Gorr The God Butcher", "Elsa Bloodstone",
    "Black Cat"
])

strategists = sorted([
    "Jeff The Land Shark", "Luna Snow", "Cloak & Dagger", "Invisible Woman", "Adam Warlock",
    "Loki", "Mantis", "Rocket Raccoon", "Gambit", "Ultron", "Deadpool Strategist", "Jubilee", "White Fox",
])

sorted_heroes = vanguards + duelists + strategists
BASE_URL = "https://rivalsmeta.com/characters/{}/matchups"
HEADERS = {"User-Agent": "Mozilla/5.0 (compatible; OptimalRivalry/1.0)"}



REQUEST_DELAY = 0.5
REQUEST_TIMEOUT = 30
print(f"{len(sorted_heroes)} heroes: {len(vanguards)} vanguards, {len(duelists)} duelists, {len(strategists)} strategists")
# Out:
# 56 heroes: 15 vanguards, 28 duelists, 13 strategists

# %% [markdown]
# ## 3. Parsing helpers

# %%
def format_hero_name(hero_name):
    """Use the URL slug as identity, independent of punctuation/display names."""
    name = hero_name.lower().replace("&", " ")
    return re.sub(r"[^a-z0-9]+", "-", name).strip("-")


def parse_matchups(html, hero, heroes=None):
    """Read named columns, without depending on image classes or cell order."""
    heroes = sorted_heroes if heroes is None else list(heroes)
    names_by_slug = {format_hero_name(name): name for name in heroes}
    soup = BeautifulSoup(html, "html.parser")
    matchups = {}
    for table in soup.find_all("table"):
        headings = [th.get_text(" ", strip=True).casefold()
                    for th in table.select("thead th")]
        if not {"hero", "win rate", "matches"}.issubset(headings):
            continue
        hero_col, rate_col, matches_col = (
            headings.index(name) for name in ("hero", "win rate", "matches")
        )
        for row in table.select("tbody tr"):
            cells = row.find_all("td", recursive=False)
            if len(cells) <= max(hero_col, rate_col, matches_col):
                raise ValueError(f"{hero}: incomplete matchup row")
            hero_cell = cells[hero_col]
            link = hero_cell.find("a", href=re.compile(r"^/characters/"))
            if link:
                slug = link["href"].split("/")[2]
            else:
                img = hero_cell.find("img", alt=True)
                name = img["alt"] if img else hero_cell.get_text(" ", strip=True)
                slug = format_hero_name(name)
            opponent = names_by_slug.get(slug)
            if opponent is None:
                raise ValueError(f"{hero}: unknown opponent {slug!r}; update the hero lists")
            rate_text = cells[rate_col].get_text("", strip=True)
            count_text = re.sub(r"[,\s]", "", cells[matches_col].get_text(strip=True))
            if not re.fullmatch(r"\d+(?:\.\d+)?\s*%", rate_text):
                raise ValueError(f"{hero} vs {opponent}: invalid win rate {rate_text!r}")
            if not re.fullmatch(r"\d+", count_text):
                raise ValueError(f"{hero} vs {opponent}: invalid match count {count_text!r}")
            rate, count = float(rate_text.rstrip("%")), int(count_text)
            if not 0 <= rate <= 100 or count <= 0:
                raise ValueError(f"{hero} vs {opponent}: win rate/count out of range")
            if opponent in matchups:
                raise ValueError(f"{hero}: duplicate matchup for {opponent}")
            matchups[opponent] = (rate, count)

    missing = set(heroes) - {hero} - matchups.keys()
    if not matchups or missing:
        raise ValueError(
            f"{hero}: missing matchup data for {', '.join(sorted(missing)) or 'all heroes'}. "
            "The page may be unavailable or its layout may have changed."
        )
    # Preserve the original model's synthetic self-match convention.
    opponent_counts = [count for name, (_, count) in matchups.items() if name != hero]
    matchups[hero] = (50.0, int(np.mean(opponent_counts)))
    return matchups

# %% [markdown]
# ## 4. Start a session and reset downloaded pages

# %%
if "session" in globals():
    session.close()
session = requests.Session()
session.headers.update(HEADERS)
retry = Retry(total=3, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
session.mount("https://", HTTPAdapter(max_retries=retry))
pages = {}
fetch_errors = {}
print("Session ready; page cache cleared.")
# Out:
# Session ready; page cache cleared.

# %% [markdown]
# ## 5. Inspect one hero before downloading everything

# %%
test_hero = "Luna Snow"
assert test_hero in sorted_heroes, "Choose a hero from sorted_heroes"
test_url = BASE_URL.format(format_hero_name(test_hero))
response = session.get(test_url, timeout=REQUEST_TIMEOUT)
print(f"HTTP {response.status_code}: {response.url}")
response.raise_for_status()
test_html = response.text
pages[test_hero] = test_html
test_soup = BeautifulSoup(test_html, "html.parser")
print("Table headings:")
for table in test_soup.find_all("table"):
    print([th.get_text(" ", strip=True) for th in table.select("thead th")])
# Out:
# HTTP 200: https://rivalsmeta.com/characters/luna-snow/matchups
# Table headings:
# ['Hero', 'Matchup', 'Win Rate', 'Difference', 'Matches']
# ['Hero', 'Matchup', 'Win Rate', 'Difference', 'Matches']
# ['Hero', 'Matchup', 'Win Rate', 'Difference', 'Matches']

# %%
test_matchups = parse_matchups(test_html, test_hero)
test_df = pd.DataFrame.from_dict(test_matchups, orient="index", columns=["Win Rate", "Matches"])
print(f"Parsed {len(test_matchups) - 1} opponents, plus the synthetic self-match.")
display(test_df)
# Out:
# Parsed 55 opponents, plus the synthetic self-match.
#                       Win Rate  Matches
# The Thing                51.74    28852
# Deadpool Vanguard        49.22    22187
# Emma Frost               48.93    73766
# Magneto                  48.92    95663
# The Hood                 47.48    60464
# Doctor Strange           46.95    68303
# Venom                    46.22    23801
# Angela                   45.70    10785
# Groot                    45.44    13260
# Rogue                    45.38    20146
# Thor                     45.28    23690
# Hulk                     44.24    22975
# Captain America          42.40    11722
# Devil Dinosaur           41.11    36135
# Peni Parker              31.66    12601
# Squirrel Girl            58.36     6420
# Phoenix                  54.83    10592
# Cyclops                  54.38    19051
# Namor                    52.06    32834
# The Punisher             51.11    27408
# Hawkeye                  51.10     6026
# ...

# %% [markdown]
# ## 6. Download the remaining hero pages

# %%
fetch_errors = {}
for i, hero in enumerate(sorted_heroes, start=1):
    if hero in pages:
        continue
    time.sleep(REQUEST_DELAY)
    url = BASE_URL.format(format_hero_name(hero))
    print(f"Fetching {hero} ({i}/{len(sorted_heroes)})...", flush=True)
    try:
        response = session.get(url, timeout=REQUEST_TIMEOUT)
        response.raise_for_status()
        pages[hero] = response.text
    except requests.RequestException as exc:
        fetch_errors[hero] = str(exc)
        print(f"  FAILED: {exc}")

print(f"Cached {sum(hero in pages for hero in sorted_heroes)}/{len(sorted_heroes)} pages.")
if fetch_errors:
    display(pd.Series(fetch_errors, name="Request error").to_frame())
# Out:
# Fetching Angela (1/56)...
# Fetching Captain America (2/56)...
# Fetching Deadpool Vanguard (3/56)...
# Fetching Devil Dinosaur (4/56)...
# Fetching Doctor Strange (5/56)...
# Fetching Emma Frost (6/56)...
# Fetching Groot (7/56)...
# Fetching Hulk (8/56)...
# Fetching Magneto (9/56)...
# Fetching Peni Parker (10/56)...
# Fetching Rogue (11/56)...
# Fetching The Hood (12/56)...
# Fetching The Thing (13/56)...
# Fetching Thor (14/56)...
# Fetching Venom (15/56)...
# Fetching Black Cat (16/56)...
# Fetching Black Panther (17/56)...
# Fetching Black Widow (18/56)...
# Fetching Blade (19/56)...
# Fetching Cyclops (20/56)...
# Fetching Daredevil (21/56)...
# Fetching Deadpool Duelist (22/56)...
# Fetching Elsa Bloodstone (23/56)...
# Fetching Gorr The God Butcher (24/56)...
# Fetching Hawkeye (25/56)...
# Fetching Hela (26/56)...
# Fetching Human Torch (27/56)...
# Fetching Iron Fist (28/56)...
# Fetching Iron Man (29/56)...
# Fetching Magik (30/56)...
# ...

# %% [markdown]
# ## 7. Parse cached pages into matrices

# %%
WinRate_df = pd.DataFrame(index=sorted_heroes, columns=sorted_heroes, dtype=float)
NumMatches_df = pd.DataFrame(index=sorted_heroes, columns=sorted_heroes, dtype=float)
parse_errors = {}
for hero in sorted_heroes:
    if hero not in pages:
        parse_errors[hero] = "Page not downloaded; retry section 6."
        continue
    try:
        matchups = parse_matchups(pages[hero], hero)
    except ValueError as exc:
        parse_errors[hero] = str(exc)
        continue
    for opponent, (rate, count) in matchups.items():
        WinRate_df.at[hero, opponent] = rate
        NumMatches_df.at[hero, opponent] = count

print(f"Parsed {len(sorted_heroes) - len(parse_errors)}/{len(sorted_heroes)} heroes.")
if parse_errors:
    display(pd.Series(parse_errors, name="Parse error").to_frame())
display(WinRate_df.head())
display(NumMatches_df.head())
# Out:
# Parsed 56/56 heroes.
#                    Angela  Captain America  Deadpool Vanguard  Devil Dinosaur  \
# Angela              50.00            46.88              52.58           48.28
# Captain America     53.13            50.00              56.99           47.49
# Deadpool Vanguard   47.42            43.01              50.00           41.53
# Devil Dinosaur      51.72            52.51              58.47           50.00
# Doctor Strange      49.71            46.90              53.08           44.71
#
#                    Doctor Strange  Emma Frost  Groot   Hulk  Magneto  \
# Angela                      50.29       53.92  45.98  47.78    52.46
# Captain America             53.10       55.51  51.89  52.74    55.20
# Deadpool Vanguard           46.92       48.46  45.04  43.44    50.01
# Devil Dinosaur              55.29       58.69  56.84  50.65    57.76
# Doctor Strange              50.00       52.13  50.14  47.38    52.43
#
# ...

# %% [markdown]
# ## 8. Validate completeness and numeric ranges
# If this fails, inspect the errors above and rerun the relevant download/parse cells. All 56 × 56 entries (including synthetic diagonals) must be present with the current roster.

# %%
def validate_matrices(win_rates, num_matches):
    for label, frame in (("Win rates", win_rates), ("Match counts", num_matches)):
        if list(frame.index) != sorted_heroes or list(frame.columns) != sorted_heroes:
            raise ValueError(f"{label}: unexpected hero labels/order")
        missing = frame.isna().sum(axis=1)
        if missing.any():
            raise ValueError(f"{label}: missing entries by hero: {missing[missing > 0].to_dict()}")
        if not np.isfinite(frame.to_numpy(dtype=float)).all():
            raise ValueError(f"{label}: non-finite values")
    if not ((win_rates >= 0) & (win_rates <= 100)).to_numpy().all():
        raise ValueError("Win rates must be between 0 and 100")
    counts = num_matches.to_numpy(dtype=float)
    if (counts <= 0).any() or (counts != np.floor(counts)).any():
        raise ValueError("Match counts must be positive integers")
    if not (np.diag(win_rates) == 50).all():
        raise ValueError("Self-match win rates must be 50%")

validate_matrices(WinRate_df, NumMatches_df)
NumMatches_df = NumMatches_df.astype("int64")
print(f"Validated {WinRate_df.shape[0]} × {WinRate_df.shape[1]} matrices; no missing values.")
# Out:
# Validated 56 × 56 matrices; no missing values.

# %% [markdown]
# ## 9. Calculate the weighted KDE payoff

# %%
validate_matrices(WinRate_df, NumMatches_df)
win_rates = WinRate_df.to_numpy(dtype=float).ravel()
num_matches = NumMatches_df.to_numpy(dtype=float).ravel()
min_value, max_value = win_rates.min(), win_rates.max()
if min_value == max_value:
    raise ValueError("Cannot fit a KDE to constant win rates")
kde = gaussian_kde(win_rates, weights=num_matches)
total_cdf = kde.integrate_box_1d(min_value, max_value)
print(f"Win-rate range: {min_value:.2f}% to {max_value:.2f}%; KDE mass: {total_cdf:.6f}")
# Out:
# Win-rate range: 25.12% to 74.88%; KDE mass: 0.999893

# %%
utilities = {
    rate: round(2 * kde.integrate_box_1d(min_value, rate) / total_cdf - 1, 2)
    for rate in np.unique(win_rates)
}
payoff_values = np.array([utilities[rate] for rate in win_rates]).reshape(WinRate_df.shape)
Payoff_df = pd.DataFrame(payoff_values, index=WinRate_df.index, columns=WinRate_df.columns)
# Save the inputs used for this payoff so export can detect stale calculations.
payoff_input_rates = pd.DataFrame(win_rates.reshape(WinRate_df.shape), index=WinRate_df.index, columns=WinRate_df.columns)
payoff_input_counts = pd.DataFrame(num_matches.reshape(NumMatches_df.shape), index=NumMatches_df.index, columns=NumMatches_df.columns)
display(Payoff_df.head())
# Out:
#                    Angela  Captain America  Deadpool Vanguard  Devil Dinosaur  \
# Angela              -0.00            -0.52               0.45           -0.31
# Captain America      0.53            -0.00               0.88           -0.43
# Deadpool Vanguard   -0.45            -0.88              -0.00           -0.93
# Devil Dinosaur       0.31             0.43               0.93           -0.00
# Doctor Strange      -0.05            -0.52               0.52           -0.76
#
#                    Doctor Strange  Emma Frost  Groot  Hulk  Magneto  \
# Angela                       0.05        0.63  -0.64 -0.39     0.43
# Captain America              0.52        0.78   0.34  0.47     0.76
# Deadpool Vanguard           -0.52       -0.28  -0.74 -0.85     0.00
# Devil Dinosaur               0.76        0.94   0.87  0.12     0.91
# Doctor Strange              -0.00        0.38   0.03 -0.45     0.42
#
#                    Peni Parker  ...  Gambit  Invisible Woman  \
# ...

# %% [markdown]
# ## 10. Export all as CSVs

# %%
validate_matrices(WinRate_df, NumMatches_df)
if not (WinRate_df.astype(float).equals(payoff_input_rates)
        and NumMatches_df.astype(float).equals(payoff_input_counts)):
    raise ValueError("Matrices changed since payoff calculation; rerun both cells in section 9")
if (not Payoff_df.index.equals(WinRate_df.index)
        or not Payoff_df.columns.equals(WinRate_df.columns)
        or not np.isfinite(Payoff_df.to_numpy()).all()
        or (np.abs(Payoff_df.to_numpy()) > 1).any()):
    raise ValueError("Invalid payoff matrix; rerun section 9")

output_dir = Path(".")
output_dir.mkdir(parents=True, exist_ok=True)
for name, frame in (("WinRate", WinRate_df), ("NumMatches", NumMatches_df), ("Payoff", Payoff_df)):
    path = output_dir / f"MarvelRivals_{name}_Matrix.csv"
    frame.to_csv(path, index=True)
    print(f"Exported {path.resolve()}")
# Out:
# Exported /Users/xool/Library/CloudStorage/OneDrive-Personal/Jupyter WorkPlace/MATH441/Optimal_Rivalry/MarvelRivals_WinRate_Matrix.csv
# Exported /Users/xool/Library/CloudStorage/OneDrive-Personal/Jupyter WorkPlace/MATH441/Optimal_Rivalry/MarvelRivals_NumMatches_Matrix.csv
# Exported /Users/xool/Library/CloudStorage/OneDrive-Personal/Jupyter WorkPlace/MATH441/Optimal_Rivalry/MarvelRivals_Payoff_Matrix.csv
